# %%
import matplotlib.pyplot as plt
import math
import numpy as np
from qiskit.circuit.library import NormalDistribution
from math import pi
from qiskit import IBMQ, BasicAer, Aer
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.visualization import plot_histogram

#Preparing the sine-shaped histogram that will be used in the initialisation

L = 1
x = np.linspace(0,L, num=10)
x = np.delete(x,[0,9])
zero = np.zeros(8)
x = np.append(x,zero)
xaxis = np.linspace(0,2*L, num=16)
storage_for_normalisation = []

Normalisation_wavefunction = (np.sqrt(2/L)*np.sin(pi*x/L))

Normalisation_Constant = np.sqrt(np.sum(Normalisation_wavefunction**2))

waveFunction = (Normalisation_wavefunction)/(Normalisation_Constant)
print(np.sum(waveFunction**2))
plt.plot(xaxis,waveFunction)
plt.show()
# Out:
# 0.9999999999999998

# %%
#n = 6 #number of qubits not including ancilla
phi = 0.01
V = 1000



qb = 4  #Number of active qubits. Not including Ancilla
cbits = 4

q = QuantumRegister(qb + 1)
c = ClassicalRegister(cbits)
qc = QuantumCircuit(q)

qc2 = QuantumCircuit(q,c)

initialisation = QuantumCircuit(q,c)

#Initialisation


def QFT(qubits):
    qc.swap(1,4)
    qc.swap(2,3)
    for i in range(qubits):
        qc.h(i+1)
        for j in range(qubits - 1 - i):
            qc.cp(pi/(2**(j+1)), i+2+j, i+1)


def Time_Evolution(qubits):
    for i in range (qubits):
        qc.p(phi/(2**(i+qubits-3)), qubits-i)
    for i in range (qubits):
        for j in range (i+1,qubits):
            qc.cx(qubits-j, 0)
            qc.cx(qubits-i, 0)
            qc.p(phi* (2**(2-i-j)), 0) #2-i-j or 4?
            qc.cx(qubits-i, 0)
            qc.cx(qubits-j, 0)


def QFT_Inv(qubits):
    for i in reversed(range(qubits)):
        for j in range(qubits - 1 - i):
            qc.cp(-pi/(2**(j+1)), i+2+j, i+1)
        qc.h(i+1)   
    qc.swap(1,4)
    qc.swap(2,3)
            
            
##############################################  INITILIZATION    ###################################################################




initialisation.initialize(waveFunction, [q[1],q[2],q[3],q[4]])

initialisation.draw()


l = 0

for l in range(10):

    qc2.initialize(waveFunction, [q[1],q[2],q[3],q[4]])

########################################### POTENTIAL   ############################################################################




    qc.p(V*phi,qb)



#########################################  QUANTUM FOURIER TRANSFORM ###################################


            
    QFT(qb)

    qc.x(qb)
    
#for k in range(qb):
#    qc.measure(k+1,k)


   #Centering the Momentum

###############################################  TIME STEP  ##############################################################
    
    
    Time_Evolution(qb)


###############################################  Inverse QFT   ####################################################


    qc.x(qb)
    
    QFT_Inv(qb)



#totqc = qc.to_gate()



    for i in range(l):
        qc2.append(qc, [0,1,2,3,4])



#Measurement


    for k in range(qb):
        qc2.measure(k+1,k)

    backend = BasicAer.get_backend('qasm_simulator')
    shots = 65536
    results = execute(qc2, backend=backend, shots=shots).result()
    answer = results.get_counts()
    for a in range(2**qb):
        s = '{0:04b}'.format(a)
        if s not in answer.keys():
            answer[s] = 0
    
    #IBMQ.load_account()
    #provider = IBMQ.get_provider('ibm-q')
    #qcomp = provider.get_backend('ibmq_vigo')
    #job = execute(qc2, backend=qcomp, shots=8192)

    #from qiskit.tools.monitor import job_monitor

    #job_monitor(job)
   # result = job.result()
    plot_histogram(answer, title = "Particle in a Step Potential", figsize = [20,10]).savefig('F:\Thesis\eigenstate\\quantumcomputer\\check\standingzzz'+ str(l) +'.png')
    
    qc2.data = []
#qc2.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fa9ac4b40204> in <module>
#     120     backend = BasicAer.get_backend('qasm_simulator')
#     121     shots = 65536
# --> 122     results = execute(qc2, backend=backend, shots=shots).result()
#     123     answer = results.get_counts()
#     124     for a in range(2**qb):
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\execute.py in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     250     else:
#     251         # transpiling the circuits using given transpile options
# --> 252         experiments = transpile(experiments,
#     253                                 basis_gates=basis_gates,
#     254                                 coupling_map=coupling_map,
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\compiler\transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     241
#     242     # Transpile circuits in parallel
# --> 243     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     244
#     245     if len(circuits) == 1:
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\tools\parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     104         return []
#     105     if len(values) == 1:
# --> 106         return [task(values[0], *task_args, **task_kwargs)]
#     107
#     108     Publisher().publish("terra.parallel.start", len(values))
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\compiler\transpile.py in _transpile_circuit(circuit_config_tuple)
#     324         raise TranspilerError("optimization_level can range from 0 to 3.")
#     325
# --> 326     result = pass_manager.run(circuit, callback=transpile_config['callback'],
#     327                               output_name=transpile_config['output_name'])
#     328
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\passmanager.py in run(self, circuits, output_name, callback)
#     223         """
#     224         if isinstance(circuits, QuantumCircuit):
# --> 225             return self._run_single_circuit(circuits, output_name, callback)
#     226         elif len(circuits) == 1:
#     227             return self._run_single_circuit(circuits[0], output_name, callback)
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     286         if callback is None and self.callback:  # TODO to remove with __init__(callback)
#     287             callback = self.callback
# --> 288         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     289         self.property_set = running_passmanager.property_set
#     290         return result
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\runningpassmanager.py in run(***failed resolving arguments***)
#     111         for passset in self.working_list:
#     112             for pass_ in passset:
# --> 113                 dag = self._do_pass(pass_, dag, passset.options)
#     114
#     115         circuit = dag_to_circuit(dag)
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     142         # Run the pass itself, if not already run
#     143         if pass_ not in self.valid_passes:
# --> 144             dag = self._run_this_pass(pass_, dag)
#     145
#     146             # update the valid_passes property
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     154             # Measure time if we have a callback or logging set
#     155             start_time = time()
# --> 156             new_dag = pass_.run(dag)
#     157             end_time = time()
#     158             run_time = end_time - start_time
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_gates.py in run(self, dag)
#      83                 # If there are any sympy objects coming from the gate convert
#      84                 # to numpy.
# ---> 85                 left_parameters = tuple([float(x) for x in left_parameters])
#      86                 # Compose gates
#      87                 name_tuple = (left_name, right_name)
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_gates.py in <listcomp>(.0)
#      83                 # If there are any sympy objects coming from the gate convert
#      84                 # to numpy.
# ---> 85                 left_parameters = tuple([float(x) for x in left_parameters])
#      86                 # Compose gates
#      87                 name_tuple = (left_name, right_name)
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\circuit\parameterexpression.py in __float__(self)
#     270
#     271     def __float__(self):
# --> 272         if self.parameters:
#     273             raise TypeError('ParameterExpression with unbound parameters ({}) '
#     274                             'cannot be cast to a float.'.format(self.parameters))
#
# ~\anaconda3\envs\quantumThesis\lib\site-packages\qiskit\circuit\parameterexpression.py in parameters(self)
#      47         self._names = None
#      48
# ---> 49     @property
#      50     def parameters(self) -> Set:
#      51         """Returns a set of the unbound Parameters in the expression."""
#
# KeyboardInterrupt:
