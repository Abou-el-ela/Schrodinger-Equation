# %%
import matplotlib.pyplot as plt
import math
import numpy as np
from qiskit.circuit.library import NormalDistribution
from math import pi
from qiskit import IBMQ, BasicAer
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.visualization import plot_histogram

#Preparing the Gaussian-shaped histogram that will be used in the initialisation
x = np.linspace(-5,5, num=8)
a = []
i=0
totsum = 0
dx = (x[1] - x[0])
hist = []
normalisedthing = 1.4141761821744954
histnorm = []

for i in range(len(x)):
    y = (1/math.sqrt(2*math.pi)*math.exp(-(0.5*x[i]**2)/2))
    
    #hist.append(y*dx)
    hist.append(y*dx/normalisedthing)
    
    histnorm.append(math.sqrt(hist[i])) 
    
    totsum = totsum + hist[i]

print(totsum)
plt.plot(x,hist)
plt.show()
# Out:
# 1.0

# %%
#n = 6 #number of qubits not including ancilla
phi = pi


q = QuantumRegister(4)
c = ClassicalRegister(3)
qc = QuantumCircuit(q,c)

qc2 = QuantumCircuit(q,c)

#Initialisation


#################################################################################################################


qc.initialize(histnorm, [q[1],q[2],q[3]])
#qc.initialize([0,0,0.5,0.5,0.5,0.5,0,0],[q[1],q[2],q[3]])

#qc2.initialize(histnorm, [q[1],q[2],q[3]])



#######################################################################################################################



#qc.initialize(amplitude, [q[1],q[2],q[3],q[4],q[5],q[6]])
#qc2.initialize(amplitude, [q[1],q[2],q[3],q[4],q[5],q[6]])

#Attempt at Gaussian Curve

#gauss = =1/(math.sqrt(2*(15)))*math.exp(-0.5*x^2)




qc.barrier()

#QFT

qc.h(1); qc.cp(pi/2,2,1); qc.cp(pi/4,3,1)
qc.h(2); qc.cp(pi/2,3,2)
qc.h(3)
qc.x(3)

#qc.swap(1,3)

qc.barrier()



#Time Step
qc.p(phi,3)
qc.p(phi/2,2)
qc.p(phi/4,1)


qc.cx(3,0); qc.cx(2,0)
qc.p(phi*2,0)
qc.cx(2,0); qc.cx(3,0)


qc.cx(3,0); qc.cx(1,0)
qc.p(phi,0)
qc.cx(1,0); qc.cx(3,0)



#qc.cx(3,0); qc.cx(2,0); qc.cx(1,0)
#qc.p(2*phi,0)
#qc.cx(1,0); qc.cx(2,0); qc.cx(3,0)

qc.cx(2,0); qc.cx(1,0)
qc.p(phi/2,0)
qc.cx(1,0); qc.cx(2,0)




qc.barrier()




#Inverse QFT

qc.x(3)
qc.h(3)
qc.cp(-pi/2,3,2); qc.h(2)
qc.cp(-pi/2,2,1); qc.cp(-pi/4,3,1); qc.h(1)

#qc.swap(1,3)




qc.barrier()


#Measurement

for k in range(3):
    qc.measure(k+1,k)
    qc2.measure(k+1,k)




qc.draw('mpl')

# %%
# use local simulator
backend = BasicAer.get_backend('qasm_simulator')
shots = 65536
results = execute(qc, backend=backend, shots=shots).result()
answer = results.get_counts()

plot_histogram(answer)
